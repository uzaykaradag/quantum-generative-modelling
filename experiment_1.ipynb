# %% [markdown]
# ## Experiment one

# %%
! pip install qujax
# Out:
# Collecting qujax
#   Using cached qujax-1.1.0-py3-none-any.whl.metadata (11 kB)
# Collecting jax (from qujax)
#   Downloading jax-0.4.26-py3-none-any.whl.metadata (23 kB)
# Collecting jaxlib (from qujax)
#   Downloading jaxlib-0.4.26-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting ml-dtypes>=0.2.0 (from jax->qujax)
#   Downloading ml_dtypes-0.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.22 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (1.26.4)
# Collecting opt-einsum (from jax->qujax)
#   Using cached opt_einsum-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: scipy>=1.9 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (1.12.0)
# Using cached qujax-1.1.0-py3-none-any.whl (25 kB)
# Downloading jax-0.4.26-py3-none-any.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 36.1 MB/s eta 0:00:00:00:01
# Downloading jaxlib-0.4.26-cp311-cp311-manylinux2014_x86_64.whl (78.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 MB 17.6 MB/s eta 0:00:00:00:0100:01
# Downloading ml_dtypes-0.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 78.3 MB/s eta 0:00:00
# Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Installing collected packages: opt-einsum, ml-dtypes, jaxlib, jax, qujax
# Successfully installed jax-0.4.26 jaxlib-0.4.26 ml-dtypes-0.4.0 opt-einsum-3.3.0 qujax-1.1.0

# %%
import pickle
with open(f'./numerical_sim/bi_gaussain/gen_data.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
## Plot function 
def plot_histogram_and_line(data, final_st):
    fig, ax = plt.subplots()
    
    # Plot histogram for data
    ax.hist(data, bins=50, density=True, alpha=0.5, label="Data")
    
    # Plot line for Final Parameter
    ax.plot(final_st, label="Final Parameter", color='orange')
    
    # Plot line for Averaged over parameters
   # ax.plot(data_avg, label="Averaged over parameters", linestyle='--', color='orange')
    
    # Adjust plot settings
    ax.set_xlim(data.min(), data.max())
    ax.set_ylabel("Probability")
    ax.set_xlabel("Data $\mu$m")
    ax.legend()
    
    return fig

## Simulation functions
def expected_kernel(kernel, data1, weights1, data2, weights2):
    from jax import numpy as jnp, random, vmap, grad, value_and_grad, jit

    def row_eval(data1_single):
        return (vmap(kernel, in_axes=(None, 0))(data1_single, data2) * weights2).sum()

    return (vmap(row_eval)(data1) * weights1).sum()


def mmd(kernel, data1, weights1, data2, weights2):

    return (
        expected_kernel(kernel, data1, weights1, data1, weights1)
        - 2 * expected_kernel(kernel, data1, weights1, data2, weights2)
        + expected_kernel(kernel, data2, weights2, data2, weights2)
    )

def get_stepsize( step):
    return (step + 10) **(-1/3)

def get_circuit(n_qubits, depth):
    n_params = 2 * n_qubits * (depth + 1)

    gates = ["H"] * n_qubits + ["Rx"] * n_qubits + ["Ry"] * n_qubits
    qubit_inds = [[i] for i in range(n_qubits)] * 3
    param_inds = [[]] * n_qubits + [[i] for i in range(n_qubits * 2)]

    k = 2 * n_qubits

    for _ in range(depth):
        for i in range(0, n_qubits - 1):
            gates.append("CZ")
            qubit_inds.append([i, i + 1])
            param_inds.append([])
        for i in range(n_qubits):
            gates.append("Rx")
            qubit_inds.append([i])
            param_inds.append([k])
            k += 1
        for i in range(n_qubits):
            gates.append("Ry")
            qubit_inds.append([i])
            param_inds.append([k])
            k += 1
    return gates, qubit_inds, param_inds, n_params


def gaussian_kernel(s1, s2, bandwidth_sq):
    return jnp.exp(-jnp.square(s1 - s2) / bandwidth_sq)

def param_to_mmd(param, param_to_st):
    from jax import numpy as jnp
    st = param_to_st(param)
    probs = jnp.square(jnp.abs(st.flatten()))
    return mmd(lambda s1, s2: gaussian_kernel(s1, s2, bandwidth_sq), jnp.arange(st.size), probs, data, data_probs)


def param_to_mmd_stochastic(param, param_to_st, data, bandwidth_sq, batch_size):
    data_probs = jnp.ones(batch_size) / batch_size
    st = param_to_st(param)
    probs = jnp.square(jnp.abs(st.flatten()))
    return mmd(lambda s1, s2: gaussian_kernel(s1, s2, bandwidth_sq), jnp.arange(st.size), probs, np.random.choice(data, batch_size), data_probs)

def compute_av_probs(params, param_to_st, burn_in = 100):
    from jax import numpy as jnp, vmap
    probs = vmap(lambda p: jnp.square(jnp.abs(param_to_st(p).flatten())))(params[burn_in:])
    return probs.mean(axis=0)

# %%
def G(p, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    return mu_inv * (p.T @ M_inv @ p - N_d * kBT)

def A_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    q = q + h * M_inv @ p
    return q,p,xi

def B_step(q,p,xi,h,force, params_for_sgada):
    p = p + h * force(q) 
    return q,p,xi

def O_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    
    term1 = np.exp(-xi*h) * p
    term2 = sigma_a * np.sqrt((1 - np.exp(-2 * xi * h)) / (2 * xi)) * np.random.randn(p.shape[0])
    p = term1 + term2
    return q,p,xi

def D_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    xi = xi + h * G(p, params_for_sgada)
    return q,p,xi

def ld_BADODAB(q,p,xi,h,force, params_for_sgada):

    q, p, xi = np.copy(q), np.copy(p), np.copy(xi)
    q, p, xi = B_step(q,p,xi,h/2,force,params_for_sgada)
    q, p, xi = A_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = D_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = O_step(q,p,xi,h,   params_for_sgada)
    q, p, xi = D_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = A_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = B_step(q,p,xi,h/2,force, params_for_sgada)

    return q, p, xi

# %%
def run_simulation_SGADA(q0, p0, xi0,step_function,force,hyperparameters,train_keys):
    #q0, p0, xi0, Nsteps, h, step_function, force):
    h, M, mu_inv, N_d, beta, sigma, sigma_a, n_steps, n_qubits, circuit_depth, batch_size = hyperparameters.values()

    bar_length = 30
    
    q_traj = [q0]
    p_traj = [p0]
    xi_traj = [xi0]
    cost_vals = []

    q = q0
    p = p0
    xi = xi0

    M_inv = M
    kBT     = 1 / beta
    params_for_sgada = (M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, batch_size)

    
    start_time = time.time()  # Record the start time

    for n in range(n_steps):
        # if stochastic_flag:
        #     cost_val, cost_grad = value_and_grad(param_to_mmd_stochastic)(q_traj[n - 1], param_to_st, data, bandwidth_sq, batch_size)
        # else:
        #     cost_val, cost_grad = value_and_grad(param_to_mmd)(q_traj[n - 1], param_to_st, data_probs, bandwidth_sq, data)
        cost_val, cost_grad = param_to_mmd_and_grad(q_traj[n - 1])
        
        q,p,xi = step_function(q, p, xi, h, force, params_for_sgada)

        cost_vals.append(cost_val)
        

        q_traj += [q]
        p_traj += [p]
        xi_traj += [xi]
        
        progress = (n+1) / n_steps
        filled_length = int(bar_length * progress)
        bar = '█' * filled_length + '-' * (bar_length - filled_length)
        
        elapsed_time = time.time() - start_time  # Compute the elapsed time
        remaining_time = (elapsed_time / (n + 1)) * (n_steps - n - 1)  # Estimate the remaining time

        
        print(f'\rProgress: |{bar}| {progress:.2%} | Iteration: {n+1}/{n_steps} | Cost: {cost_val:.6f} | Elapsed Time: {elapsed_time:.2f}s | Estimated Remaining Time: {remaining_time:.2f}s', end='')    
    print()  # Move to the next line after the progress bar
    
    total_run_time = time.time() - start_time  # Compute the total run time
    
    return q_traj, p_traj, xi_traj, cost_vals, total_run_time

# %%
def run_simulation_SGLD(init_param,n_params,hyperparameters,train_keys):
    import time
    h,beta, n_steps, n_qubits, circuit_depth, batch_size = hyperparameters.values()

    bar_length = 30

    params = jnp.zeros((n_steps, n_params))
    params = params.at[0].set(init_param)

    cost_vals = jnp.zeros(n_steps - 1)

    start_time = time.time() # Record the start time

    # compute before the loop as they are reused
    gamma = jnp.sqrt(2*h/ beta)

    for step in range(1, n_steps):
        cost_val, cost_grad = param_to_mmd_and_grad(params[step - 1])

        cost_vals = cost_vals.at[step - 1].set(cost_val)

        # stepsize = get_stepsize(step)

        new_param = (
            params[step - 1]
            - h * cost_grad
            + gamma
            * random.normal(train_keys[step - 1], shape=(n_params,))
        )
        params = params.at[step].set(new_param)

        progress = (step+1) / n_steps
        filled_length = int(bar_length * progress)
        bar = '█' * filled_length + '-' * (bar_length - filled_length)
        elapsed_time = time.time() - start_time # Compute the elapsed time
        remaining_time = (elapsed_time / step) * (n_steps - step) # Estimate the remaining time
        print(f'\rProgress: |{bar}| {progress:.2%} | Iteration: {step}/{n_steps} | Cost: {cost_val:.6f} | Elapsed Time: {elapsed_time:.2f}s | Estimated Remaining Time: {remaining_time:.2f}s', end='')

    print() # Move to the next line after the progress bar

    total_run_time = time.time() - start_time # Compute the total run time

    return params, cost_vals, total_run_time

# %%
from jax import numpy as jnp, random, vmap, grad, value_and_grad, jit
import matplotlib.pyplot as plt
import qujax
import jax
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
import os

# %%
output_folder = "Experiment_1"

qubit_range = [2, 4, 6, 8, 10]
depth_range = [1, 2, 3, 4, 5]
beta = 100
h_step_size = 0.1
n_steps = 5000
stochastic_flag= False

sgada_hyperparams = {
    'h': 0.1, 'M': None ,'mu_inv': 1., 'N_d': 1., 'beta': beta, 'sigma': 1., 'sigma_a': 1.00,
    'n_steps': n_steps, 'n_qubits': None, 'circuit_depth': None,'batch_size': 200
}

sgld_hyperparams = {
    'h':0.1,'beta': beta, 'n_steps': n_steps, 'n_qubits': None, 'circuit_depth': None,'batch_size': 200
}


random_key = random.PRNGKey(0)
init_key, train_key = random.split(random_key)
bandwidth_sq = 5.7478714 #jnp.median(dist_mat) / 2
init_rad = 0.001 / jnp.pi


for n_qubits in qubit_range:
    for circuit_depth in depth_range:
        print(f"Running experiment for n_qubits={n_qubits}, circuit_depth={circuit_depth}")
        
        gates, qubit_inds, param_inds, n_params = get_circuit(n_qubits, circuit_depth)
        param_to_st = qujax.get_params_to_statetensor_func(gates, qubit_inds, param_inds)
        data_probs = jnp.ones(len(data)) / len(data)

        if stochastic_flag:
            param_to_mmd_and_grad = jit(value_and_grad(lambda param: param_to_mmd_stochastic(param, param_to_st)))
        else:
            param_to_mmd_and_grad = jit(value_and_grad(lambda param: param_to_mmd(param, param_to_st)))

        train_keys = random.split(train_key, sgld_hyperparams['n_steps'] - 1)

        init_param = random.uniform(
            init_key, shape=(n_params,), minval=-init_rad, maxval=init_rad
        )


        # Update hyperparameters with the current n_qubits and circuit_depth
        sgada_hyperparams['n_qubits'] = n_qubits
        sgada_hyperparams['circuit_depth'] = circuit_depth
        sgada_hyperparams['M'] = jnp.eye(n_params)
        
        sgld_hyperparams['n_qubits'] = n_qubits
        sgld_hyperparams['circuit_depth'] = circuit_depth
        
        
        # Run SGLD model
        sgld_output, sgld_cost_vals, sgld_run_time =  run_simulation_SGLD(
              init_param, n_params,sgld_hyperparams,train_keys
        )


        # Run SGADA model
        sgada_output, sgada_p_traj, sgada_xi_traj, sgada_cost_vals, sgada_total_run_time = run_simulation_SGADA(
            init_param, np.random.randn(n_params), 0.0, ld_BADODAB, (lambda q: -param_to_mmd_and_grad(q)[1]) ,sgada_hyperparams,train_keys
        )



        model_SGADA = {
            'params': sgada_output,
            'cost_vals': sgada_cost_vals,
            'run_time': sgada_total_run_time,
            'p_traj': sgada_p_traj,
            'xi_traj': sgada_xi_traj
        }

        model_SGLD = {
            'params': sgld_output,
            'cost_vals': sgld_cost_vals,
            'run_time': sgld_run_time,
        }
     
        # Save results to files
        filename = f"results_nqubits_{n_qubits}_depth_{circuit_depth}.pkl"
        filepath = os.path.join(output_folder, filename)

        results = {
            'n_qubits': n_qubits,
            'circuit_depth': circuit_depth,
            'sgld': model_SGLD,
            'sqada': model_SGADA
        }

        with open(filepath, 'wb') as f:
            pickle.dump(results, f)

        print(f"Results saved to {filepath}")
# Out:
# Running experiment for n_qubits=2, circuit_depth=1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.829891 | Elapsed Time: 100.54s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.824648 | Elapsed Time: 293.41s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_2_depth_1.pkl
# Running experiment for n_qubits=2, circuit_depth=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.834695 | Elapsed Time: 100.79s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.822650 | Elapsed Time: 293.04s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_2_depth_2.pkl
# Running experiment for n_qubits=2, circuit_depth=3
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.840572 | Elapsed Time: 101.00s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.811381 | Elapsed Time: 293.61s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_2_depth_3.pkl
# Running experiment for n_qubits=2, circuit_depth=4
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.817752 | Elapsed Time: 101.00s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.813711 | Elapsed Time: 293.05s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_2_depth_4.pkl
# Running experiment for n_qubits=2, circuit_depth=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.842122 | Elapsed Time: 101.32s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.812858 | Elapsed Time: 292.43s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_2_depth_5.pkl
# Running experiment for n_qubits=4, circuit_depth=1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.033813 | Elapsed Time: 100.97s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.044811 | Elapsed Time: 291.70s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_4_depth_1.pkl
# Running experiment for n_qubits=4, circuit_depth=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.030000 | Elapsed Time: 101.07s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.010991 | Elapsed Time: 289.91s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_4_depth_2.pkl
# Running experiment for n_qubits=4, circuit_depth=3
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.014209 | Elapsed Time: 102.98s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.012254 | Elapsed Time: 290.28s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_4_depth_3.pkl
# Running experiment for n_qubits=4, circuit_depth=4
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.032025 | Elapsed Time: 102.95s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.011442 | Elapsed Time: 290.39s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_4_depth_4.pkl
# Running experiment for n_qubits=4, circuit_depth=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.045101 | Elapsed Time: 105.40s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.025213 | Elapsed Time: 291.42s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_4_depth_5.pkl
# Running experiment for n_qubits=6, circuit_depth=1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.029335 | Elapsed Time: 104.05s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.041618 | Elapsed Time: 298.61s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_6_depth_1.pkl
# Running experiment for n_qubits=6, circuit_depth=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.066097 | Elapsed Time: 105.74s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.025832 | Elapsed Time: 300.96s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_6_depth_2.pkl
# Running experiment for n_qubits=6, circuit_depth=3
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.062843 | Elapsed Time: 107.94s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.028841 | Elapsed Time: 301.06s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_6_depth_3.pkl
# Running experiment for n_qubits=6, circuit_depth=4
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.087565 | Elapsed Time: 109.38s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.010974 | Elapsed Time: 302.03s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_6_depth_4.pkl
# Running experiment for n_qubits=6, circuit_depth=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.056056 | Elapsed Time: 112.00s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.011982 | Elapsed Time: 301.85s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_6_depth_5.pkl
# Running experiment for n_qubits=8, circuit_depth=1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.089524 | Elapsed Time: 108.54s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.038423 | Elapsed Time: 308.57s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_8_depth_1.pkl
# Running experiment for n_qubits=8, circuit_depth=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.071219 | Elapsed Time: 110.17s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.051115 | Elapsed Time: 307.95s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_8_depth_2.pkl
# Running experiment for n_qubits=8, circuit_depth=3
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.100962 | Elapsed Time: 112.28s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.049487 | Elapsed Time: 308.95s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_8_depth_3.pkl
# Running experiment for n_qubits=8, circuit_depth=4
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.222132 | Elapsed Time: 116.19s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.015361 | Elapsed Time: 308.61s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_8_depth_4.pkl
# Running experiment for n_qubits=8, circuit_depth=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.193231 | Elapsed Time: 119.92s | Estimated Remaining Time: 0.02s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.055307 | Elapsed Time: 309.48s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_8_depth_5.pkl
# Running experiment for n_qubits=10, circuit_depth=1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.107920 | Elapsed Time: 134.70s | Estimated Remaining Time: 0.03s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.043831 | Elapsed Time: 374.59s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_10_depth_1.pkl
# Running experiment for n_qubits=10, circuit_depth=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.225917 | Elapsed Time: 139.14s | Estimated Remaining Time: 0.03s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.038049 | Elapsed Time: 379.62s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_10_depth_2.pkl
# Running experiment for n_qubits=10, circuit_depth=3
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.099996 | Elapsed Time: 146.86s | Estimated Remaining Time: 0.03s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.063403 | Elapsed Time: 384.38s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_10_depth_3.pkl
# Running experiment for n_qubits=10, circuit_depth=4
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.300018 | Elapsed Time: 153.33s | Estimated Remaining Time: 0.03s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.040393 | Elapsed Time: 390.10s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_10_depth_4.pkl
# Running experiment for n_qubits=10, circuit_depth=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.359646 | Elapsed Time: 160.78s | Estimated Remaining Time: 0.03s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.028243 | Elapsed Time: 396.22s | Estimated Remaining Time: 0.00ss
# Results saved to Experiment_1/results_nqubits_10_depth_5.pkl

# %%
import os
import pickle
import matplotlib.pyplot as plt

output_folder = "Experiment_1"

qubit_range = [2, 4, 6, 8, 10]
depth_range = [1, 2, 3, 4, 5]

num_rows = len(qubit_range)
num_cols = len(depth_range)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(40, 40))

for i, n_qubits in enumerate(qubit_range):
    for j, circuit_depth in enumerate(depth_range):
        filename = f"results_nqubits_{n_qubits}_depth_{circuit_depth}.pkl"
        filepath = os.path.join(output_folder, filename)

        with open(filepath, 'rb') as f:
            results = pickle.load(f)

        sgld_cost_vals = results['sgld']['cost_vals']
        sgada_cost_vals = results['sqada']['cost_vals']

        ax = axes[i, j]
        ax.plot(sgld_cost_vals, label='SGLD')
        ax.plot(sgada_cost_vals, label='SGADA')
        
        # Check if 'beta' key exists in the results dictionary
        if 'beta' in results['sgld']:
            beta_value = results['sgld']['beta']
            ax.set_title(f'n_qubits={n_qubits}, depth={circuit_depth}, beta={beta_value}')
        else:
            ax.set_title(f'n_qubits={n_qubits}, depth={circuit_depth}')
        
        ax.set_xlabel("Iteration")
        ax.set_ylabel("MMD")
        ax.set_ylim(0, 0.4)
        ax.legend()

fig.tight_layout()
plt.show()

# %%
import os
import pickle
import matplotlib.pyplot as plt

output_folder = "Experiment_1"
qubit_range = [2, 4, 6, 8, 10]
depth_range = [1, 2, 3, 4, 5]

num_rows = len(qubit_range)
num_cols = len(depth_range)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(40, 40))

for i, n_qubits in enumerate(qubit_range):
    for j, circuit_depth in enumerate(depth_range):
        filename = f"results_nqubits_{n_qubits}_depth_{circuit_depth}.pkl"
        filepath = os.path.join(output_folder, filename)
        
        with open(filepath, 'rb') as f:
            results = pickle.load(f)

        
        ax = axes[i, j]
        
        # Plot histogram for data
        ax.hist(data, bins=50, density=True, alpha=0.5, label="Data")
        gates, qubit_inds, param_inds, n_params = get_circuit(n_qubits, circuit_depth)
        param_to_st = qujax.get_params_to_statetensor_func(gates, qubit_inds, param_inds)
        
        burn_in = 1000
        
        for model_name in ['sgld', 'sqada']:
            params = results[model_name]['params']
            
            # Compute the averaged probabilities over the last burn_in steps
            av_probs = jnp.square(jnp.abs(param_to_st(np.array(params[-burn_in:]).mean(0)).flatten()))
            # Plot line for Averaged Parameters
            ax.plot(av_probs, label=f"{model_name.upper()} - Averaged Parameters", linewidth=2)
        
        # Check if 'beta' key exists in the results dictionary
        ax.set_ylim(0, 0.3)
        ax.set_xlim(4,20)
        if 'beta' in results['sgld']:
            beta_value = results['sgld']['beta']
            ax.set_title(f'n_qubits={n_qubits}, depth={circuit_depth}, beta={beta_value}')
        else:
            ax.set_title(f'n_qubits={n_qubits}, depth={circuit_depth}')
        
        ax.set_xlabel("Iteration")
        ax.set_ylabel("MMD")
        ax.legend()

fig.tight_layout()
plt.show()

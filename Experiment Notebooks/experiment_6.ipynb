# %%
# !pip install qujax
# Out:
# /srv/conda/envs/notebook/lib/python3.11/pty.py:89: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   pid, fd = os.forkpty()
# Requirement already satisfied: qujax in /srv/conda/envs/notebook/lib/python3.11/site-packages (1.1.0)
# Requirement already satisfied: jax in /srv/conda/envs/notebook/lib/python3.11/site-packages (from qujax) (0.4.26)
# Requirement already satisfied: jaxlib in /srv/conda/envs/notebook/lib/python3.11/site-packages (from qujax) (0.4.26)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (0.4.0)
# Requirement already satisfied: numpy>=1.22 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (1.26.4)
# Requirement already satisfied: opt-einsum in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (3.3.0)
# Requirement already satisfied: scipy>=1.9 in /srv/conda/envs/notebook/lib/python3.11/site-packages (from jax->qujax) (1.12.0)

# %%
import pickle
with open(f'./numerical_sim/bi_gaussain/gen_data.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
## Plot function 
def plot_histogram_and_line(data, final_st):
    fig, ax = plt.subplots()
    
    # Plot histogram for data
    ax.hist(data, bins=50, density=True, alpha=0.5, label="Data")
    
    # Plot line for Final Parameter
    ax.plot(final_st, label="Final Parameter", color='orange')
    
    # Plot line for Averaged over parameters
   # ax.plot(data_avg, label="Averaged over parameters", linestyle='--', color='orange')
    
    # Adjust plot settings
    ax.set_xlim(data.min(), data.max())
    ax.set_ylabel("Probability")
    ax.set_xlabel("Data $\mu$m")
    ax.legend()
    
    return fig

## Simulation functions
def expected_kernel(kernel, data1, weights1, data2, weights2):
    from jax import numpy as jnp, random, vmap, grad, value_and_grad, jit

    def row_eval(data1_single):
        return (vmap(kernel, in_axes=(None, 0))(data1_single, data2) * weights2).sum()

    return (vmap(row_eval)(data1) * weights1).sum()


def mmd(kernel, data1, weights1, data2, weights2):

    return (
        expected_kernel(kernel, data1, weights1, data1, weights1)
        - 2 * expected_kernel(kernel, data1, weights1, data2, weights2)
        + expected_kernel(kernel, data2, weights2, data2, weights2)
    )

def get_stepsize( step):
    return (step + 10) **(-1/3)

def get_circuit(n_qubits, depth):
    n_params = 2 * n_qubits * (depth + 1)

    gates = ["H"] * n_qubits + ["Rx"] * n_qubits + ["Ry"] * n_qubits
    qubit_inds = [[i] for i in range(n_qubits)] * 3
    param_inds = [[]] * n_qubits + [[i] for i in range(n_qubits * 2)]

    k = 2 * n_qubits

    for _ in range(depth):
        for i in range(0, n_qubits - 1):
            gates.append("CZ")
            qubit_inds.append([i, i + 1])
            param_inds.append([])
        for i in range(n_qubits):
            gates.append("Rx")
            qubit_inds.append([i])
            param_inds.append([k])
            k += 1
        for i in range(n_qubits):
            gates.append("Ry")
            qubit_inds.append([i])
            param_inds.append([k])
            k += 1
    return gates, qubit_inds, param_inds, n_params


def gaussian_kernel(s1, s2, bandwidth_sq):
    return jnp.exp(-jnp.square(s1 - s2) / bandwidth_sq)

def param_to_mmd(param, param_to_st):
    from jax import numpy as jnp
    st = param_to_st(param)
    probs = jnp.square(jnp.abs(st.flatten()))
    return mmd(lambda s1, s2: gaussian_kernel(s1, s2, bandwidth_sq), jnp.arange(st.size), probs, data, data_probs)


def param_to_mmd_stochastic(param, param_to_st, batch_size):
    data_probs = jnp.ones(batch_size) / batch_size
    st = param_to_st(param)
    probs = jnp.square(jnp.abs(st.flatten()))
    return mmd(lambda s1, s2: gaussian_kernel(s1, s2, bandwidth_sq), jnp.arange(st.size), probs, np.random.choice(data, batch_size), data_probs)

def compute_av_probs(params, param_to_st, burn_in = 100):
    from jax import numpy as jnp, vmap
    probs = vmap(lambda p: jnp.square(jnp.abs(param_to_st(p).flatten())))(params[burn_in:])
    return probs.mean(axis=0)

# %%
from jax import numpy as jnp, random, vmap, grad, value_and_grad, jit
import matplotlib.pyplot as plt
import qujax
import jax
import numpy as np
import matplotlib.pyplot as plt
import time
import pickle
import os

def G(p, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    return mu_inv * (p.T @ M_inv @ p - N_d * kBT)

def A_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    q = q + h * M_inv @ p
    return q,p,xi

def B_step(q,p,xi,h,force, params_for_sgada):
    p = p + h * force(q)
    return q,p,xi

def O_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, _ = params_for_sgada
    term1 = np.exp(-xi*h) * p
    term2 = sigma_a * np.sqrt((1 - np.exp(-2 * xi * h)) / (2 * xi)) * np.random.randn(p.shape[0])
    p = term1 + term2
    return q,p,xi

def D_step(q,p,xi,h, params_for_sgada):
    from jax import numpy as jnp
    import numpy as np
    xi = xi + h * G(p, params_for_sgada)
    return q,p,xi

def ld_BADODAB(q,p,xi,h,force, params_for_sgada):
    q, p, xi = np.copy(q), np.copy(p), np.copy(xi)
    q, p, xi = B_step(q,p,xi,h/2,force,params_for_sgada)
    q, p, xi = A_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = D_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = O_step(q,p,xi,h, params_for_sgada)
    q, p, xi = D_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = A_step(q,p,xi,h/2, params_for_sgada)
    q, p, xi = B_step(q,p,xi,h/2,force, params_for_sgada)
    return q, p, xi

def run_simulation_SGAdL(alpha, q0, p0, xi0,step_function,force,hyperparameters,train_keys):
    #q0, p0, xi0, Nsteps, h, step_function, force):
    h, M, mu_inv, N_d, beta, sigma, sigma_a, n_steps, n_qubits, circuit_depth, batch_size = hyperparameters.values()
    
    bar_length = 30
    
    q_traj = [q0]
    p_traj = [p0]
    xi_traj = [xi0]
    cost_vals = []
    
    q = q0
    p = p0
    xi = xi0
    M_inv = M
    kBT = 1 / beta
    params_for_sgada = (M, M_inv, mu_inv, N_d, kBT, sigma, sigma_a, batch_size)

    start_time = time.time() # Record the start time

    for n in range(n_steps):
        cost_val, cost_grad = param_to_mmd_and_grad(q_traj[n - 1])
        
        # Add noise to the cost_grad
        noise = random.normal(train_keys[n - 1], shape=cost_grad.shape, dtype=jnp.float32)
        cost_grad = cost_grad + alpha * noise
        
        q,p,xi = step_function(q, p, xi, h, force, params_for_sgada)
        cost_vals.append(cost_val)
        q_traj += [q]
        p_traj += [p]
        xi_traj += [xi]

        progress = (n+1) / n_steps
        filled_length = int(bar_length * progress)
        bar = '█' * filled_length + '-' * (bar_length - filled_length)
        elapsed_time = time.time() - start_time # Compute the elapsed time
        remaining_time = (elapsed_time / (n + 1)) * (n_steps - n - 1) # Estimate the remaining time
        print(f'\rProgress: |{bar}| {progress:.2%} | Iteration: {n+1}/{n_steps} | Cost: {cost_val:.6f} | Elapsed Time: {elapsed_time:.2f}s | Estimated Remaining Time: {remaining_time:.2f}s', end='')

    print() # Move to the next line after the progress bar

    total_run_time = time.time() - start_time # Compute the total run time

    return q_traj, p_traj, xi_traj, cost_vals, total_run_time


def run_simulation_SGLD(alpha,init_param,n_params,hyperparameters,train_keys):
    import time

    h,beta, n_steps, n_qubits, circuit_depth, batch_size = hyperparameters.values()
    
    bar_length = 30

    params = jnp.zeros((n_steps, n_params))
    params = params.at[0].set(init_param)
    cost_vals = jnp.zeros(n_steps - 1)

    start_time = time.time() # Record the start time
    
    # compute before the loop as they are reused
    gamma = jnp.sqrt(2*h/ beta)
    
    for step in range(1, n_steps):
        cost_val, cost_grad = param_to_mmd_and_grad(params[step - 1])
        
        # Add noise to the cost_grad
        noise = random.normal(train_keys[step - 1], shape=cost_grad.shape, dtype=jnp.float32)
        cost_grad = cost_grad + alpha * noise
        
        cost_vals = cost_vals.at[step - 1].set(cost_val)
        
        # stepsize = get_stepsize(step)
        new_param = (
            params[step - 1]
            - h * cost_grad
            + gamma
            * random.normal(train_keys[step - 1], shape=(n_params,))
        )
        params = params.at[step].set(new_param)

        progress = (step+1) / n_steps
        filled_length = int(bar_length * progress)
        bar = '█' * filled_length + '-' * (bar_length - filled_length)
        elapsed_time = time.time() - start_time # Compute the elapsed time
        remaining_time = (elapsed_time / step) * (n_steps - step) # Estimate the remaining time
        print(f'\rProgress: |{bar}| {progress:.2%} | Iteration: {step}/{n_steps} | Cost: {cost_val:.6f} | Elapsed Time: {elapsed_time:.2f}s | Estimated Remaining Time: {remaining_time:.2f}s', end='')

    print() # Move to the next line after the progress bar

    total_run_time = time.time() - start_time # Compute the total run time

    return params, cost_vals, total_run_time

# %%
output_folder = "experiment_6"

mu_inv_range =  [0.01, 0.1, 1.0, 2, 5, 10.0]
sigma_a_range = [0.01, 0.1, 1.0, 2, 5, 10.0]

stochastic_flag = True
qubit = 8
depth = 4
n_qubits = 8
circuit_depth = 4
beta = 100
alpha = 0
n_steps = 5000
batch_size= 200
h_step_size = 0.1

random_key = random.PRNGKey(0)
init_key, train_key = random.split(random_key)

bandwidth_sq = 5.7478714 # jnp.median(dist_mat) / 2
init_rad = 0.001 / jnp.pi

for mu_inv in mu_inv_range:
    for sigma_a in sigma_a_range:
        print(f"Running experiment for mu_inv={mu_inv}, sigma_a={sigma_a}")

        sgadl_hyperparams = {
            'h': h_step_size, 'M': None, 'mu_inv': mu_inv, 'N_d': 1., 'beta': beta, 'sigma': 1., 'sigma_a': sigma_a,
            'n_steps': n_steps, 'n_qubits': qubit, 'circuit_depth': None, 'batch_size': batch_size
        }
        
        sgld_hyperparams = {
            'h': h_step_size, 'beta': beta, 'n_steps': n_steps, 'n_qubits': qubit, 'circuit_depth': depth, 'batch_size': batch_size
        }

        gates, qubit_inds, param_inds, n_params = get_circuit(n_qubits, circuit_depth)
        param_to_st = qujax.get_params_to_statetensor_func(gates, qubit_inds, param_inds)
        data_probs = jnp.ones(len(data)) / len(data)
        
        if stochastic_flag:
            param_to_mmd_and_grad = jit(value_and_grad(lambda param: param_to_mmd_stochastic(param, param_to_st, batch_size)))
        else:
            param_to_mmd_and_grad = jit(value_and_grad(lambda param: param_to_mmd(param, param_to_st)))
        
        train_keys = random.split(train_key, sgld_hyperparams['n_steps'] - 1)

        init_param = random.uniform(
            init_key, shape=(n_params,), minval=-init_rad, maxval=init_rad
        )
        
        # Update hyperparameters with the current n_qubits and circuit_depth
        sgadl_hyperparams['M'] = jnp.eye(n_params)
        
        # Run SGLD model
        sgld_output, sgld_cost_vals, sgld_run_time = run_simulation_SGLD(
            alpha, init_param, n_params, sgld_hyperparams, train_keys
        )
        
        # Run SGADA model
        sgada_output, sgada_p_traj, sgada_xi_traj, sgada_cost_vals, sgada_total_run_time = run_simulation_SGAdL(
            alpha, init_param, np.random.randn(n_params), 0.0, ld_BADODAB, (lambda q: -param_to_mmd_and_grad(q)[1]), sgadl_hyperparams, train_keys
        )

        model_SGAdL = {
            'params': sgada_output,
            'cost_vals': sgada_cost_vals,
            'run_time': sgada_total_run_time,
            'p_traj': sgada_p_traj,
            'xi_traj': sgada_xi_traj
        }

        model_SGLD = {
            'params': sgld_output,
            'cost_vals': sgld_cost_vals,
            'run_time': sgld_run_time,
        }

        # Save results to files
        filename = f"results_mu_inv_{mu_inv}_sigma_a_{sigma_a}.pkl"
        filepath = os.path.join(output_folder, filename)

        results = {
            'mu_inv': mu_inv,
            'sigma_a': sigma_a,
            'sgld': model_SGLD,
            'sgadl': model_SGAdL
        }

        with open(filepath, 'wb') as f:
            pickle.dump(results, f)

        print(f"Results saved to {filepath}")
# Out:
# Running experiment for mu_inv=0.01, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.282203 | Elapsed Time: 30.47s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.000846 | Elapsed Time: 29.57s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_0.01.pkl
# Running experiment for mu_inv=0.01, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.139793 | Elapsed Time: 32.76s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.021328 | Elapsed Time: 28.86s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_0.1.pkl
# Running experiment for mu_inv=0.01, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.169917 | Elapsed Time: 32.49s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.363449 | Elapsed Time: 28.19s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_1.0.pkl
# Running experiment for mu_inv=0.01, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.253915 | Elapsed Time: 30.64s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.333569 | Elapsed Time: 26.65s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_2.pkl
# Running experiment for mu_inv=0.01, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.134238 | Elapsed Time: 29.45s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.350492 | Elapsed Time: 26.78s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_5.pkl
# Running experiment for mu_inv=0.01, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.156619 | Elapsed Time: 30.56s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.363009 | Elapsed Time: 26.45s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.01_sigma_a_10.0.pkl
# Running experiment for mu_inv=0.1, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.255806 | Elapsed Time: 29.83s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.000352 | Elapsed Time: 29.14s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_0.01.pkl
# Running experiment for mu_inv=0.1, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.168838 | Elapsed Time: 29.98s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.007958 | Elapsed Time: 28.69s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_0.1.pkl
# Running experiment for mu_inv=0.1, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.123168 | Elapsed Time: 30.97s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.167404 | Elapsed Time: 28.28s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_1.0.pkl
# Running experiment for mu_inv=0.1, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.211648 | Elapsed Time: 32.10s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.201804 | Elapsed Time: 28.24s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_2.pkl
# Running experiment for mu_inv=0.1, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.161052 | Elapsed Time: 32.28s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.311663 | Elapsed Time: 29.32s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_5.pkl
# Running experiment for mu_inv=0.1, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.240703 | Elapsed Time: 32.40s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.365836 | Elapsed Time: 29.21s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_0.1_sigma_a_10.0.pkl
# Running experiment for mu_inv=1.0, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.071608 | Elapsed Time: 31.23s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.000162 | Elapsed Time: 25.90s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_0.01.pkl
# Running experiment for mu_inv=1.0, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.129401 | Elapsed Time: 34.67s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.003524 | Elapsed Time: 26.93s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_0.1.pkl
# Running experiment for mu_inv=1.0, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.157006 | Elapsed Time: 35.05s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.019571 | Elapsed Time: 26.26s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_1.0.pkl
# Running experiment for mu_inv=1.0, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.173403 | Elapsed Time: 32.48s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.053141 | Elapsed Time: 29.83s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_2.pkl
# Running experiment for mu_inv=1.0, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.114626 | Elapsed Time: 35.38s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.253056 | Elapsed Time: 29.34s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_5.pkl
# Running experiment for mu_inv=1.0, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.173890 | Elapsed Time: 36.52s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.308519 | Elapsed Time: 29.61s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_1.0_sigma_a_10.0.pkl
# Running experiment for mu_inv=2, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.181343 | Elapsed Time: 34.11s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.000326 | Elapsed Time: 29.06s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_0.01.pkl
# Running experiment for mu_inv=2, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.105835 | Elapsed Time: 36.78s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.002394 | Elapsed Time: 31.15s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_0.1.pkl
# Running experiment for mu_inv=2, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.157063 | Elapsed Time: 32.87s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.027369 | Elapsed Time: 30.57s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_1.0.pkl
# Running experiment for mu_inv=2, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.182837 | Elapsed Time: 37.09s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.026231 | Elapsed Time: 29.27s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_2.pkl
# Running experiment for mu_inv=2, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.173217 | Elapsed Time: 31.10s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.112419 | Elapsed Time: 31.59s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_5.pkl
# Running experiment for mu_inv=2, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.148115 | Elapsed Time: 35.92s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.194896 | Elapsed Time: 31.16s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_2_sigma_a_10.0.pkl
# Running experiment for mu_inv=5, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.225961 | Elapsed Time: 37.51s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.001553 | Elapsed Time: 29.90s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_0.01.pkl
# Running experiment for mu_inv=5, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.219057 | Elapsed Time: 33.19s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.001252 | Elapsed Time: 29.11s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_0.1.pkl
# Running experiment for mu_inv=5, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.116833 | Elapsed Time: 31.75s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.018177 | Elapsed Time: 30.06s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_1.0.pkl
# Running experiment for mu_inv=5, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.253119 | Elapsed Time: 38.05s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.019792 | Elapsed Time: 27.78s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_2.pkl
# Running experiment for mu_inv=5, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.146761 | Elapsed Time: 32.92s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.052230 | Elapsed Time: 30.48s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_5.pkl
# Running experiment for mu_inv=5, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.096753 | Elapsed Time: 36.66s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.063356 | Elapsed Time: 27.63s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_5_sigma_a_10.0.pkl
# Running experiment for mu_inv=10.0, sigma_a=0.01
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.263200 | Elapsed Time: 35.69s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.001260 | Elapsed Time: 29.45s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_0.01.pkl
# Running experiment for mu_inv=10.0, sigma_a=0.1
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.156433 | Elapsed Time: 34.54s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.002198 | Elapsed Time: 28.59s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_0.1.pkl
# Running experiment for mu_inv=10.0, sigma_a=1.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.132140 | Elapsed Time: 32.95s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.011158 | Elapsed Time: 29.25s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_1.0.pkl
# Running experiment for mu_inv=10.0, sigma_a=2
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.208128 | Elapsed Time: 31.92s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.009280 | Elapsed Time: 29.25s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_2.pkl
# Running experiment for mu_inv=10.0, sigma_a=5
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.129728 | Elapsed Time: 33.86s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.041771 | Elapsed Time: 27.79s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_5.pkl
# Running experiment for mu_inv=10.0, sigma_a=10.0
# Progress: |██████████████████████████████| 100.00% | Iteration: 4999/5000 | Cost: 0.265801 | Elapsed Time: 31.98s | Estimated Remaining Time: 0.01s
# Progress: |██████████████████████████████| 100.00% | Iteration: 5000/5000 | Cost: 0.103325 | Elapsed Time: 29.01s | Estimated Remaining Time: 0.00s
# Results saved to experiment_6/results_mu_inv_10.0_sigma_a_10.0.pkl

# %%
import os
import pickle
import matplotlib.pyplot as plt

output_folder = "experiment_6"

mu_inv_range = [0.01, 0.1, 1.0, 10.0]
sigma_a_range = [0.01, 0.1, 1.0, 10.0]

stochastic_flag = True
qubit = 8
depth = 4
n_qubits = 8
circuit_depth = 4
beta = 100
alpha = 0
n_steps = 5000
batch_size = 200
h_step_size = 0.1

num_rows = len(mu_inv_range)
num_cols = len(sigma_a_range)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5*num_cols, 5*num_rows))

for i, mu_inv in enumerate(mu_inv_range):
    for j, sigma_a in enumerate(sigma_a_range):
        filename = f"results_mu_inv_{mu_inv}_sigma_a_{sigma_a}.pkl"
        filepath = os.path.join(output_folder, filename)

        with open(filepath, 'rb') as f:
            results = pickle.load(f)

        #sgld_cost_vals = results['sgld']['cost_vals']
        sgadl_cost_vals = results['sgadl']['cost_vals']

        ax = axes[i, j]
        #ax.plot( sgld_cost_vals, label='SGLD')
        ax.plot( sgadl_cost_vals, label='SGAdL')
        ax.set_title(f'mu_inv={mu_inv}, sigma_a={sigma_a}')
        ax.set_xlabel("Iteration")
        ax.set_ylabel("MMD")
        ax.set_ylim(0, 0.4)
        # ax.legend()
# Save the figure as an image file
image_folder = "images"
image_filename = "experiment_6_grid_plot_mmd.png"
image_filepath = os.path.join(image_folder, image_filename)
plt.savefig(image_filepath)

fig.tight_layout()
plt.show()

# %%
import os
import pickle
import matplotlib.pyplot as plt
import numpy as np
import jax.numpy as jnp
import qujax

output_folder = "experiment_6"

mu_inv_range = [0.01, 0.1, 1.0, 10.0]
sigma_a_range = [0.01, 0.1, 1.0, 10.0]

stochastic_flag = True
qubit = 8
depth = 4
n_qubits = 8
circuit_depth = 4
beta = 100
alpha = 0
n_steps = 5000
batch_size = 200
h_step_size = 0.1

burn_in = 1000

num_rows = len(mu_inv_range)
num_cols = len(sigma_a_range)

fig, axes = plt.subplots(num_rows, num_cols, figsize=(5*num_cols, 5*num_rows))

for i, mu_inv in enumerate(mu_inv_range):
    for j, sigma_a in enumerate(sigma_a_range):
        filename = f"results_mu_inv_{mu_inv}_sigma_a_{sigma_a}.pkl"
        filepath = os.path.join(output_folder, filename)

        with open(filepath, 'rb') as f:
            results = pickle.load(f)

        ax = axes[i, j]

        # Plot histogram for data
        ax.hist(data, bins=50, density=True, alpha=0.5, label="Data")

        gates, qubit_inds, param_inds, n_params = get_circuit(n_qubits, circuit_depth)
        param_to_st = qujax.get_params_to_statetensor_func(gates, qubit_inds, param_inds)

        for model_name in ['sgadl']:
            params = results[model_name]['params']

            # Compute the averaged probabilities over the last burn_in steps
            av_probs = jnp.square(jnp.abs(param_to_st(np.array(params[-burn_in:]).mean(0)).flatten()))

            # Plot line for Averaged Parameters
            ax.plot(av_probs, label=f"{model_name.upper()} - Averaged Parameters", linewidth=2)

        ax.set_ylim(0, 0.3)
        ax.set_xlim(4, 20)
        ax.set_title(f'mu_inv={mu_inv}, sigma_a={sigma_a}')
        ax.set_xlabel("State Index x")
        ax.set_ylabel("Probability")
        # ax.legend()
# Save the figure as an image file
image_filename = "experiment_6_grid_plot_p.png"
image_filepath = os.path.join(image_folder, image_filename)
plt.savefig(image_filepath)

fig.tight_layout()
plt.show()
